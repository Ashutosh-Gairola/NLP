# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashutosh-Gairola/NLP/blob/main/LAB_5(19_09_2024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
def preprocess(text):
  tokens=word_tokenize(text)
  words = [word.lower() for word in tokens if word.isalpha()]
  lemmatizer = WordNetLemmatizer()
  words = [lemmatizer.lemmatize(word) for word in words]
  return words

# %%
def word_sense_disambiguation(word):
  synsets = wordnet.synsets(word)
  if synsets:
    return synsets[0]
  else:
    return None

# %%
from math import hypot
def get_word_info(word):
    sense = word_sense_disambiguation(word)
    if sense:
        synonyms = [lemma.name() for lemma in sense.lemmas()]
        antonyms = []
        for lemma in sense.lemmas():
            antonyms.extend(lemma.antonyms())
        antonyms = [antonym.name() for antonym in antonyms]
        hypernyms = [hypernym.name() for hypernym in sense.hypernyms()]
        hyponyms = [hyponym.name() for hyponym in sense.hyponyms()]  # Added this line

        return {
            'synonyms': synonyms,
            'antonyms': antonyms,
            'hypernyms': hypernyms,
            'hyponyms': hyponyms  # Now 'hyponyms' is defined
        }
    else:
        return None

# %%
def main(file_path):
  with open(file_path,'r') as file:
    text=file.read()
  words=preprocess(text)
  word_info_dict={}
  for word in words:
    if word not in word_info_dict:
      word_info=get_word_info(word)
      if word_info:
        word_info_dict[word]=word_info
  for word,info in word_info_dict.items():
    print(f"Word: {word}")
    print(f"Synonyms: {', '.join(info['synonyms'])}")
    print(f"Antonyms: {', '.join(info['antonyms'])}")
    print(f"Hypernyms: {', '.join(info['hypernyms'])}")
    print(f"Hyponyms: {', '.join(info['hyponyms'])}")
    print("\n")

# %%
if __name__ == "__main__":
  file_path = "/content/drive/MyDrive/Colab Notebooks/NLP_Sem7_pythonLab/New Text Document.txt"
  main(file_path)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Word: flying
# Synonyms: flight, flying
# Antonyms:
# Hypernyms: air_travel.n.01
# Hyponyms: acrobatics.n.02, ballooning.n.01, blind_flying.n.01, flyover.n.02, glide.n.03, maiden_flight.n.01, overflight.n.01, pass.n.07, solo.n.03, sortie.n.02, terrain_flight.n.01
#
#
# Word: present
# Synonyms: present, nowadays
# Antonyms:
# Hypernyms: time.n.05
# Hyponyms: date.n.05, here_and_now.n.01, now.n.01, time_being.n.01, today.n.01, tonight.n.01
#
#
# Word: problem
# Synonyms: problem, job
# Antonyms:
# Hypernyms: difficulty.n.03
# Hyponyms: balance-of-payments_problem.n.01, race_problem.n.01
#
#
# Word: hear
# Synonyms: hear
# Antonyms:
# Hypernyms: perceive.v.01
# Hyponyms: catch.v.14, catch.v.21
#
#
# Word: temperature
# Synonyms: temperature
# Antonyms:
# Hypernyms: fundamental_quantity.n.01, physical_property.n.01
# Hyponyms: absolute_temperature.n.01, absolute_zero.n.01, body_temperature.n.01, boiling_point.n.01, coldness.n.03, curie_temperature.n.01, dew_point.n.01, flash_point.n.02, freezing_point.n.01, hotness.n.01, mercury.n.04, room_temperature.n.01, simmer.n.01
#
#
# Word: exceeding
# Synonyms: exceed, transcend, surpass
# Antonyms:
# Hypernyms:
# Hyponyms: overgrow.v.01
#
#
# Word: below
# Synonyms: below, at_a_lower_place, to_a_lower_place, beneath
# Antonyms: above
# Hypernyms:
# Hyponyms:
#
#
# Word: zero
# Synonyms: nothing, nil, nix, nada, null, aught, cipher, cypher, goose_egg, naught, zero, zilch, zip, zippo
# Antonyms:
# Hypernyms: relative_quantity.n.01
# Hyponyms: bugger_all.n.01, nihil.n.01
#
#
# Word: blowing
# Synonyms: blowing
# Antonyms:
# Hypernyms: processing.n.01
# Hyponyms: insufflation.n.01
#
#
# Word: snow
# Synonyms: snow, snowfall
# Antonyms:
# Hypernyms: precipitation.n.03
# Hyponyms: flurry.n.02, whiteout.n.01
#
#
# Word: crystal
# Synonyms: crystal
# Antonyms:
# Hypernyms: solid.n.01
# Hyponyms: gem.n.02, ice.n.01, ice_crystal.n.01, snowflake.n.01, twins.n.01
#
#
# Word: whiteout
# Synonyms: whiteout
# Antonyms:
# Hypernyms: snow.n.01
# Hyponyms:
#
#
# Word: challenge
# Synonyms: challenge
# Antonyms:
# Hypernyms: situation.n.01
# Hyponyms:
#
#
# Word: daily
# Synonyms: daily
# Antonyms:
# Hypernyms: newspaper.n.01
# Hyponyms:
#
#
# Word: work
# Synonyms: work
# Antonyms:
# Hypernyms: activity.n.01
# Hyponyms: action.n.10, busywork.n.01, care.n.01, coursework.n.01, duty.n.02, heavy_lifting.n.01, housewifery.n.01, housework.n.01, investigation.n.02, ironing.n.02, job.n.06, job.n.07, labor.n.02, logging.n.01, loose_end.n.01, mission.n.04, nightwork.n.01, operation.n.07, paperwork.n.01, service.n.01, shining.n.01, spadework.n.01, subbing.n.01, timework.n.01, undertaking.n.01, wash.n.02, welfare_work.n.01
#
#
# Word: preheating
# Synonyms: preheat
# Antonyms:
# Hypernyms: heat.v.01
# Hyponyms:
#
#
# Word: engine
# Synonyms: engine
# Antonyms:
# Hypernyms: motor.n.01
# Hyponyms: aircraft_engine.n.01, automobile_engine.n.01, auxiliary_engine.n.01, generator.n.02, heat_engine.n.01, reaction-propulsion_engine.n.01
#
#
# Word: coax
# Synonyms: coaxial_cable, coax, coax_cable
# Antonyms:
# Hypernyms: cable.n.02
# Hyponyms: ethernet_cable.n.01
#
#
# Word: congealed
# Synonyms: jell, set, congeal
# Antonyms:
# Hypernyms: solidify.v.02
# Hyponyms:
#
#
# Word: oil
# Synonyms: oil
# Antonyms:
# Hypernyms: lipid.n.01
# Hyponyms: almond_oil.n.01, animal_oil.n.01, babassu_oil.n.01, calamus_oil.n.01, camphor_oil.n.01, chaulmoogra_oil.n.01, cohune-nut_oil.n.01, croton_oil.n.01, essential_oil.n.01, fixed_oil.n.01, fuel_oil.n.01, fusel_oil.n.01, grease.n.01, hydnocarpus_oil.n.01, hyssop_oil.n.01, lemongrass.n.01, linseed_oil.n.01, mineral_oil.n.01, motor_oil.n.01, mustard_oil.n.01, neroli_oil.n.01, pennyroyal_oil.n.01, pennyroyal_oil.n.02, petroleum.n.01, rape_oil.n.01, safflower_oil.n.01, sassafras_oil.n.01, shale_oil.n.01, spike_lavender_oil.n.01, stand_oil.n.01, tall_oil.n.01, tung_oil.n.01
#
#
# Word: propeller
# Synonyms: propeller, propellor
# Antonyms:
# Hypernyms: mechanical_device.n.01
# Hyponyms: airplane_propeller.n.01, screw.n.03, variable-pitch_propeller.n.01
#
#
# Word: pitch
# Synonyms: pitch
# Antonyms:
# Hypernyms: sound_property.n.01
# Hyponyms: alto.n.04, alto.n.05, bass.n.01, concert_pitch.n.01, high_pitch.n.01, key.n.03, low_pitch.n.01, soprano.n.03, tenor.n.02, tone.n.02, tune.n.02
#
#
# Word: mechanism
# Synonyms: mechanism, chemical_mechanism
# Antonyms:
# Hypernyms: chemical_process.n.01
# Hyponyms: biochemical_mechanism.n.01
#
#
# Word: fueling
# Synonyms: fueling, refueling
# Antonyms:
# Hypernyms: provision.n.02
# Hyponyms:
#
#
# Word: super
# Synonyms: superintendent, super
# Antonyms:
# Hypernyms: caretaker.n.01
# Hyponyms:
#
#
# Word: cooled
# Synonyms: cool, chill, cool_down
# Antonyms: heat
# Hypernyms: change.v.01
# Hyponyms: ice.v.03, quench.v.06, refrigerate.v.02
#
#
# Word: gasoline
# Synonyms: gasoline, gasolene, gas, petrol
# Antonyms:
# Hypernyms: fuel.n.01, hydrocarbon.n.01
# Hyponyms: leaded_gasoline.n.01, napalm.n.01, unleaded_gasoline.n.01
#
#
# Word: regular
# Synonyms: regular, habitue, fixture
# Antonyms:
# Hypernyms: patron.n.01
# Hyponyms:
#
#
# Word: chore
# Synonyms: job, task, chore
# Antonyms:
# Hypernyms: duty.n.02
# Hyponyms: ball-buster.n.02, scut_work.n.01, stint.n.03
#
#
# Word: must
# Synonyms: must
# Antonyms:
# Hypernyms: necessity.n.02
# Hyponyms:
#
#
# Word: be
# Synonyms: beryllium, Be, glucinium, atomic_number_4
# Antonyms:
# Hypernyms: metallic_element.n.01
# Hyponyms:
#
#
# Word: tied
# Synonyms: tie, bind
# Antonyms: untie
# Hypernyms: fasten.v.01
# Hyponyms: band.v.01, cord.v.02, gag.v.03, knot.v.02, lace.v.04, lash.v.04, lash_together.v.01, loop.v.05, retie.v.01, rope.v.02, strap.v.01, tie_up.v.05, truss.v.01
#
#
# Word: rope
# Synonyms: rope
# Antonyms:
# Hypernyms: line.n.18
# Hyponyms: bola.n.02, brace.n.05, brail.n.02, bungee.n.01, cable.n.03, cordage.n.02, guide_rope.n.01, halyard.n.01, hangman's_rope.n.01, harpoon_line.n.01, hawser.n.01, jump_rope.n.01, lashing.n.02, lasso.n.02, prolonge.n.01, small_stuff.n.01, tier.n.04, tightrope.n.01, trip_line.n.01
#
#
# Word: frozen
# Synonyms: freeze, stop_dead
# Antonyms:
# Hypernyms: stand_still.v.01
# Hyponyms: fixate.v.04
#
#
# Word: hole
# Synonyms: hole
# Antonyms:
# Hypernyms: opening.n.01
# Hyponyms: aperture.n.02, bolt-hole.n.01, bullet_hole.n.01, cranny.n.02, knothole.n.01, leak.n.01, ozone_hole.n.01, perforation.n.02, rathole.n.01
#
#
# Word: four
# Synonyms: four, 4, IV, tetrad, quatern, quaternion, quaternary, quaternity, quartet, quadruplet, foursome, Little_Joe
# Antonyms:
# Hypernyms: digit.n.01
# Hyponyms:
#
#
# Word: foot
# Synonyms: foot, human_foot, pes
# Antonyms:
# Hypernyms: vertebrate_foot.n.01
# Hyponyms: flatfoot.n.02
#
#
# Word: lifted
# Synonyms: raise, lift, elevate, get_up, bring_up
# Antonyms: lower
# Hypernyms: move.v.02
# Hyponyms: chin.v.01, get_up.v.04, heighten.v.04, hike.v.01, hoist.v.01, hoist.v.02, hoist.v.03, jack.v.01, kick_up.v.01, levitate.v.01, pick_up.v.01, pinnacle.v.02, pump.v.07, raise.v.15, rear.v.04, shoulder.v.01, skid.v.02, trice.v.01, underlay.v.01
#
#
# Word: run
# Synonyms: run, tally
# Antonyms:
# Hypernyms: score.n.10
# Hyponyms: earned_run.n.01, run_batted_in.n.01, unearned_run.n.01
#
#
# Word: board
# Synonyms: board
# Antonyms:
# Hypernyms: committee.n.01
# Hyponyms: advisory_board.n.01, appeal_board.n.01, board_of_selectmen.n.01, directorate.n.01, draft_board.n.01, federal_reserve_board.n.01, governing_board.n.01, school_board.n.01, zoning_board.n.01
#
#
# Word: pole
# Synonyms: pole
# Antonyms:
# Hypernyms: rod.n.01
# Hyponyms: barge_pole.n.01, boom.n.04, caber.n.01, clothes_tree.n.01, mast.n.04, ski_pole.n.01, spar.n.02, stilt.n.02
#
#
# Word: prevent
# Synonyms: prevent, forestall, foreclose, preclude, forbid
# Antonyms:
# Hypernyms:
# Hyponyms: debar.v.02, obstruct.v.01, save.v.06, stop.v.03, thwart.v.01
#
#
# Word: freezing
# Synonyms: freeze, freezing
# Antonyms:
# Hypernyms: cooling.n.01, phase_change.n.01
# Hyponyms: freeze-drying.n.01, frost.n.03
#
#
# Word: passenger
# Synonyms: passenger, rider
# Antonyms:
# Hypernyms: traveler.n.01
# Hyponyms: commuter.n.02, fare.n.03, hitchhiker.n.01, stowaway.n.01, straphanger.n.02
#
#
# Word: wear
# Synonyms: wear
# Antonyms:
# Hypernyms: deterioration.n.01
# Hyponyms:
#
#
# Word: heavy
# Synonyms: heavy
# Antonyms:
# Hypernyms: actor.n.01
# Hyponyms:
#
#
# Word: arctic
# Synonyms: Arctic, Arctic_Zone, North_Frigid_Zone
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: clothing
# Synonyms: clothing, article_of_clothing, vesture, wear, wearable, habiliment
# Antonyms:
# Hypernyms: consumer_goods.n.01, covering.n.02
# Hyponyms: accessory.n.01, apparel.n.01, array.n.03, attire.n.01, beachwear.n.01, black.n.07, blue.n.02, change.n.07, civilian_clothing.n.01, drag.n.04, footwear.n.01, garment.n.01, grey.n.06, handwear.n.01, headdress.n.01, knitwear.n.01, leisure_wear.n.01, loungewear.n.01, man's_clothing.n.01, neckpiece.n.01, nightwear.n.01, outerwear.n.01, protective_garment.n.01, ready-to-wear.n.01, slip-on.n.01, slops.n.02, street_clothes.n.01, tailor-made.n.01, togs.n.01, uniform.n.01, vestiture.n.01, woman's_clothing.n.01, work-clothing.n.01
#
#
# Word: few
# Synonyms: few
# Antonyms:
# Hypernyms: elite.n.01
# Hyponyms:
#
#
# Word: heat
# Synonyms: heat, heat_energy
# Antonyms:
# Hypernyms: energy.n.01
# Hyponyms: geothermal_energy.n.01, heat_of_dissociation.n.01, heat_of_formation.n.01, heat_of_solution.n.01, latent_heat.n.01, specific_heat.n.01
#
#
# Word: system
# Synonyms: system
# Antonyms:
# Hypernyms: instrumentality.n.03
# Hyponyms: audio_system.n.01, communication_system.n.01, computer_system.n.01, containment.n.02, control_system.n.01, data_system.n.01, drainage_system.n.01, exhaust.n.02, explosive_detection_system.n.01, explosive_trace_detection.n.01, guidance_system.n.01, hookup.n.02, inertial_guidance_system.n.01, lockage.n.02, maze.n.01, mechanical_system.n.01, navigational_system.n.01, network.n.04, network.n.05, propulsion_system.n.01, resonator.n.03, scaffolding.n.01, security_system.n.01, selsyn.n.01, shipboard_system.n.01, solar_thermal_system.n.01, sprinkler_system.n.01, synchromesh.n.01
#
#
# Word: capable
# Synonyms: capable
# Antonyms: incapable
# Hypernyms:
# Hyponyms:
#
#
# Word: coping
# Synonyms: header, coping, cope
# Antonyms:
# Hypernyms: brick.n.01
# Hyponyms:
#
#
# Word: cold
# Synonyms: cold, common_cold
# Antonyms:
# Hypernyms: communicable_disease.n.01, respiratory_disease.n.01
# Hyponyms: head_cold.n.01
#
#
# Word: battery
# Synonyms: battery
# Antonyms:
# Hypernyms: artillery.n.02
# Hyponyms:
#
#
# Word: removed
# Synonyms: remove, take, take_away, withdraw
# Antonyms:
# Hypernyms:
# Hyponyms: ablate.v.02, amputate.v.01, aspirate.v.01, bail.v.05, bail_out.v.02, bone.v.02, brush.v.05, bur.v.01, burl.v.01, carve_out.v.02, chip_away.v.01, circumcise.v.02, clean.v.02, clean.v.07, clean.v.08, clean.v.10, clear.v.05, clear.v.24, clear_off.v.01, condense.v.03, crumb.v.03, de-iodinate.v.01, de-ionate.v.01, decalcify.v.02, decarbonize.v.01, decorticate.v.02, defang.v.01, defuse.v.01, degas.v.01, dehorn.v.01, delete.v.01, delouse.v.01, demineralize.v.01, desorb.v.02, detoxify.v.01, dig.v.01, discharge.v.04, disembowel.v.01, dislodge.v.01, draw.v.05, draw.v.07, draw.v.17, draw_off.v.01, dredge.v.03, eliminate.v.07, empty.v.04, enucleate.v.01, enucleate.v.02, epilate.v.01, excavate.v.04, exenterate.v.01, expectorate.v.01, extirpate.v.03, extract.v.01, flick.v.09, gut.v.02, harvest.v.02, head.v.09, hull.v.01, husk.v.01, hypophysectomize.v.01, knock_out.v.03, ladle.v.02, leach.v.01, leach.v.03, lift.v.11, lift.v.22, lift.v.23, muck.v.01, pick.v.05, pit.v.03, pull.v.17, ream.v.02, resect.v.01, scale.v.06, scalp.v.02, scavenge.v.04, scoop.v.01, seed.v.08, shed.v.01, shell.v.07, shuck.v.01, shuck.v.02, skim.v.06, spoon.v.01, stem.v.04, string.v.06, strip.v.03, strip.v.08, strip.v.10, strip.v.11, strip.v.13, take_away.v.01, take_away.v.03, take_off.v.02, take_out.v.06, tear_away.v.01, tip.v.09, tusk.v.02, unburden.v.02, undock.v.02, unhinge.v.02, unpack.v.01, unsaddle.v.01, unstring.v.01, unveil.v.03, wash.v.09, wear_away.v.02, weed.v.01, winnow.v.04, wipe_off.v.01, withdraw.v.09
#
#
# Word: end
# Synonyms: end, terminal
# Antonyms:
# Hypernyms: extremity.n.04
# Hyponyms: bitter_end.n.02, bitthead.n.01, end_point.n.01, finish.n.04, heel.n.04, heel.n.05, nerve_ending.n.01, point.n.15, pole.n.10, railhead.n.02, telomere.n.01, terminus.n.04, tip.n.01, yardarm.n.01
#
#
# Word: each
# Synonyms: each
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: day
# Synonyms: day, twenty-four_hours, twenty-four_hour_period, 24-hour_interval, solar_day, mean_solar_day
# Antonyms:
# Hypernyms: time_unit.n.01
# Hyponyms: date.n.01, date.n.07, eve.n.02, morrow.n.01, today.n.02, tomorrow.n.01, yesterday.n.01
#
#
# Word: ensure
# Synonyms: guarantee, ensure, insure, assure, secure
# Antonyms:
# Hypernyms:
# Hyponyms: doom.v.03, make.v.41
#
#
# Word: maximum
# Synonyms: maximum, upper_limit
# Antonyms: minimum
# Hypernyms: extremum.n.02, large_indefinite_quantity.n.01
# Hyponyms:
#
#
# Word: efficiency
# Synonyms: efficiency
# Antonyms:
# Hypernyms: ratio.n.01
# Hyponyms: figure_of_merit.n.01
#
#
# Word: next
# Synonyms: following, next
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: wing
# Synonyms: wing
# Antonyms:
# Hypernyms: organ.n.01
# Hyponyms: ala.n.02, forewing.n.01, halter.n.04, pennon.n.02, wing_case.n.01
#
#
# Word: covered
# Synonyms: cover
# Antonyms: uncover
# Hypernyms:
# Hyponyms: aluminize.v.01, bank.v.07, bark.v.02, bedaub.v.01, bind.v.07, blacklead.v.01, blanket.v.01, blindfold.v.01, blinker.v.01, board_up.v.01, bread.v.01, brush.v.06, butter.v.01, canopy.v.01, canvas.v.03, carpet.v.02, carpet.v.03, clapboard.v.01, cloak.v.03, coat.v.01, coif.v.01, concrete.v.01, cowl.v.01, crape.v.01, crown.v.04, daub.v.03, drape.v.04, dust.v.03, envelop.v.01, face.v.09, feather.v.02, felt.v.02, flake.v.02, flash.v.07, foil.v.03, frost.v.01, frost.v.02, frost.v.03, grass.v.02, gravel.v.02, grease.v.01, hold.v.31, hood.v.01, jacket.v.01, lag.v.04, laminate.v.03, lime.v.02, line.v.02, mask.v.02, mask.v.04, mask.v.05, mound_over.v.01, mulch.v.01, oil.v.01, paint.v.04, pall.v.03, paper.v.01, parcel.v.02, paste.v.03, plank.v.01, plaster.v.01, plaster.v.02, plaster.v.04, put_on.v.07, recover.v.06, roof.v.01, sheathe.v.01, sheet.v.02, smother.v.01, sod.v.01, spray.v.03, spread.v.09, spritz.v.02, steel.v.02, straw.v.01, tile.v.01, turf.v.01, veneer.v.01, wallpaper.v.01, wash.v.08, wax.v.01, whiteout.v.01, wrap.v.01
#
#
# Word: stop
# Synonyms: stop, halt
# Antonyms:
# Hypernyms: ending.n.04
# Hyponyms: cessation.n.01, stand.n.06
#
#
# Word: ingres
# Synonyms: Ingres, Jean_Auguste_Dominique_Ingres
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: build
# Synonyms: physique, build, body-build, habitus
# Antonyms:
# Hypernyms: bodily_property.n.01
# Hyponyms: body_type.n.01, dumpiness.n.01, lankiness.n.01
#
#
# Word: frost
# Synonyms: frost, hoar, hoarfrost, rime
# Antonyms:
# Hypernyms: ice.n.01
# Hyponyms:
#
#
# Word: flight
# Synonyms: flight
# Antonyms:
# Hypernyms: formation.n.01
# Hyponyms:
#
#
# Word: surface
# Synonyms: surface
# Antonyms:
# Hypernyms: artifact.n.01
# Hyponyms: bed.n.07, board.n.09, face.n.04, ground.n.10, horizontal_surface.n.01, klein_bottle.n.01, meniscus.n.03, miter.n.02, mobius_strip.n.01, plaster.n.04, screen.n.01, side.n.05, skin.n.02, spandrel.n.01, superficies.n.02, tread.n.02, vertical_surface.n.01, work_surface.n.01
#
#
# Word: fueled
# Synonyms: fuel
# Antonyms:
# Hypernyms: supply.v.01
# Hyponyms: bunker.v.02, gas_up.v.01, refuel.v.01
#
#
# Word: often
# Synonyms: frequently, often, oftentimes, oft, ofttimes
# Antonyms: infrequently, rarely
# Hypernyms:
# Hyponyms:
#
#
# Word: preheat
# Synonyms: preheat
# Antonyms:
# Hypernyms: heat.v.01
# Hyponyms:
#
#
# Word: starting
# Synonyms: start, starting
# Antonyms:
# Hypernyms: turn.n.03
# Hyponyms:
#
#
# Word: get
# Synonyms: get
# Antonyms:
# Hypernyms: return.n.11
# Hyponyms:
#
#
# Word: minus
# Synonyms: subtraction, minus
# Antonyms:
# Hypernyms: arithmetic_operation.n.01
# Hyponyms:
#
#
# Word: can
# Synonyms: can, tin, tin_can
# Antonyms:
# Hypernyms: container.n.01
# Hyponyms: beer_can.n.01, caddy.n.01, cannikin.n.02, coffee_can.n.01, milk_can.n.01, oilcan.n.01, soda_can.n.01
#
#
# Word: turned
# Synonyms: turn
# Antonyms:
# Hypernyms: move.v.03
# Hyponyms: about-face.v.01, avert.v.02, bend.v.02, caracole.v.01, corkscrew.v.01, corner.v.03, deflect.v.02, deflect.v.03, deviate.v.01, face.v.05, flip.v.01, flip.v.08, gee.v.01, gyrate.v.01, overturn.v.01, pivot.v.01, port.v.04, pronate.v.01, roll.v.01, roll_over.v.01, rotate.v.04, swerve.v.01, swing_around.v.01, turn_away.v.01, turn_off.v.02, turn_on_a_dime.v.01, turn_out.v.10, twist.v.03
#
#
# Word: ha
# Synonyms: hour_angle, HA
# Antonyms:
# Hypernyms: angular_distance.n.01
# Hyponyms:
#
#
# Word: done
# Synonyms: make, do
# Antonyms:
# Hypernyms:
# Hyponyms: overdo.v.01
#
#
# Word: flew
# Synonyms: fly, wing
# Antonyms:
# Hypernyms: travel.v.01
# Hyponyms: buzz.v.02, flight.v.02, fly_on.v.01, hover.v.03, rack.v.06, soar.v.03
#
#
# Word: after
# Synonyms: after
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: airport
# Synonyms: airport, airdrome, aerodrome, drome
# Antonyms:
# Hypernyms: airfield.n.01
# Hyponyms: heliport.n.01
#
#
# Word: lack
# Synonyms: lack, deficiency, want
# Antonyms:
# Hypernyms: need.n.01
# Hyponyms: absence.n.01, dearth.n.01, deficit.n.02, mineral_deficiency.n.01, shortness.n.02, stringency.n.01
#
#
# Word: comparison
# Synonyms: comparison, comparing
# Antonyms:
# Hypernyms: examination.n.01
# Hyponyms: analogy.n.02, collation.n.03, confrontation.n.05, contrast.n.02, likening.n.01
#
#
# Word: south
# Synonyms: South
# Antonyms:
# Hypernyms:
# Hyponyms: alabama.n.01
#
#
# Word: usually
# Synonyms: normally, usually, unremarkably, commonly, ordinarily
# Antonyms: remarkably
# Hypernyms:
# Hyponyms:
#
#
# Word: locate
# Synonyms: locate, turn_up
# Antonyms:
# Hypernyms: find.v.03
# Hyponyms: pinpoint.v.01, unearth.v.01
#
#
# Word: operator
# Synonyms: operator
# Antonyms:
# Hypernyms: function.n.01
# Hyponyms: identity.n.03, linear_operator.n.01
#
#
# Word: larger
# Synonyms: bigger, larger
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: may
# Synonyms: May
# Antonyms:
# Hypernyms: gregorian_calendar_month.n.01
# Hyponyms:
#
#
# Word: pay
# Synonyms: wage, pay, earnings, remuneration, salary
# Antonyms:
# Hypernyms: regular_payment.n.01
# Hyponyms: combat_pay.n.01, double_time.n.02, found.n.01, half-pay.n.01, living_wage.n.01, merit_pay.n.01, minimum_wage.n.01, pay_envelope.n.01, sick_pay.n.01, strike_pay.n.01, take-home_pay.n.01
#
#
# Word: airstrip
# Synonyms: airstrip, flight_strip, landing_strip, strip
# Antonyms:
# Hypernyms: airfield.n.01
# Hyponyms: flare_path.n.01
#
#
# Word: normal
# Synonyms: convention, normal, pattern, rule, formula
# Antonyms:
# Hypernyms: practice.n.05
# Hyponyms: code_of_conduct.n.01, mores.n.01, universal.n.03
#
#
# Word: procedure
# Synonyms: procedure, process
# Antonyms:
# Hypernyms: activity.n.01
# Hyponyms: bertillon_system.n.01, calculation.n.01, condition.n.08, diagnostic_procedure.n.01, emergency_procedure.n.01, experimental_procedure.n.01, fingerprinting.n.01, genetic_profiling.n.01, indirection.n.01, mapping.n.02, medical_procedure.n.01, operating_procedure.n.01, rigmarole.n.02, routine.n.01, rule.n.11, stiffening.n.01
#
#
# Word: buzz
# Synonyms: buzz, bombilation, bombination
# Antonyms:
# Hypernyms: sound.n.04
# Hyponyms:
#
#
# Word: town
# Synonyms: town
# Antonyms:
# Hypernyms: municipality.n.01
# Hyponyms: boom_town.n.01, burg.n.01, cow_town.n.01, ghost_town.n.01, hometown.n.01, main_street.n.02, market_town.n.01
#
#
# Word: arrival
# Synonyms: arrival, reaching
# Antonyms:
# Hypernyms: accomplishment.n.01
# Hyponyms: advent.n.01, attainment.n.02
#
#
# Word: let
# Synonyms: Lashkar-e-Taiba, Lashkar-e-Toiba, Lashkar-e-Tayyiba, LET, Army_of_the_Pure, Army_of_the_Righteous
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: people
# Synonyms: people
# Antonyms:
# Hypernyms: group.n.01
# Hyponyms: age_group.n.01, ancients.n.01, baffled.n.01, blind.n.01, blood.n.05, brave.n.02, business_people.n.01, chosen_people.n.01, class.n.03, clientele.n.01, coevals.n.01, damned.n.01, dead.n.01, deaf.n.01, defeated.n.01, disabled.n.01, doomed.n.01, enemy.n.03, episcopacy.n.01, folk.n.01, free.n.01, homebound.n.01, initiate.n.03, living.n.02, lobby.n.02, mentally_retarded.n.01, migration.n.02, nation.n.02, nationality.n.01, network_army.n.01, peanut_gallery.n.01, peoples.n.01, pocket.n.07, poor_people.n.01, populace.n.01, population.n.01, rank_and_file.n.02, retreated.n.01, rich_people.n.01, sick.n.01, smart_money.n.03, timid.n.01, tradespeople.n.01, unconfessed.n.01, unemployed_people.n.01, uninitiate.n.01, womankind.n.01, wounded.n.01
#
#
# Word: know
# Synonyms: know
# Antonyms:
# Hypernyms: knowing.n.01
# Hyponyms:
#
#
# Word: landing
# Synonyms: landing
# Antonyms:
# Hypernyms: platform.n.01
# Hyponyms:
#
#
# Word: someone
# Synonyms: person, individual, someone, somebody, mortal, soul
# Antonyms:
# Hypernyms: causal_agent.n.01, organism.n.01
# Hyponyms: abator.n.01, abjurer.n.01, abomination.n.01, abstainer.n.02, achiever.n.01, acquaintance.n.03, acquirer.n.01, active.n.03, actor.n.02, adjudicator.n.01, admirer.n.02, adoptee.n.01, adult.n.01, adventurer.n.01, adversary.n.01, advisee.n.01, advocate.n.01, affiant.n.01, african.n.01, agnostic.n.01, amateur.n.01, amerindian.n.01, ancient.n.02, anomaly.n.02, anti-american.n.01, anti.n.01, applicant.n.01, appointee.n.02, appreciator.n.01, apprehender.n.02, aquarius.n.01, archaist.n.01, aries.n.01, arrogator.n.01, assessee.n.01, asthmatic.n.01, authority.n.02, autodidact.n.01, baby_boomer.n.01, baby_buster.n.01, bad_guy.n.01, bad_person.n.01, baldhead.n.01, balker.n.01, bather.n.02, beard.n.03, bedfellow.n.02, bereaved.n.01, best.n.02, birth.n.05, biter.n.01, black.n.05, blogger.n.01, blond.n.01, bluecoat.n.01, bodybuilder.n.01, bomber.n.02, brunet.n.01, bullfighter.n.01, buster.n.04, cancer.n.02, candidate.n.02, capitalist.n.02, capricorn.n.01, captor.n.01, case.n.06, cashier.n.02, celebrant.n.01, censor.n.01, chameleon.n.01, changer.n.01, charmer.n.02, child.n.03, chutzpanik.n.01, closer.n.01, clumsy_person.n.01, collector.n.01, color-blind_person.n.01, combatant.n.01, commoner.n.01, communicator.n.01, complexifier.n.01, compulsive.n.01, computer_user.n.01, contemplative.n.01, contestant.n.01, convert.n.01, copycat.n.01, counter.n.05, counterterrorist.n.01, coward.n.01, crawler.n.02, creator.n.02, creature.n.02, creditor.n.01, cripple.n.01, dancer.n.02, dead_person.n.01, deaf_person.n.01, debaser.n.01, debtor.n.01, defecator.n.01, delayer.n.01, deliverer.n.04, demander.n.01, dieter.n.01, differentiator.n.01, disentangler.n.01, disputant.n.01, dissenter.n.01, divider.n.02, domestic_partner.n.01, double.n.03, dresser.n.02, dribbler.n.02, drug_user.n.01, dyslectic.n.01, ectomorph.n.01, effecter.n.01, elizabethan.n.01, emotional_person.n.01, endomorph.n.01, engineer.n.01, enjoyer.n.01, enrollee.n.01, entertainer.n.01, ethnic.n.01, experimenter.n.02, expert.n.01, explorer.n.01, extrovert.n.01, face.n.05, faddist.n.01, faller.n.02, fastener.n.01, female.n.02, fiduciary.n.01, first-rater.n.01, follower.n.01, free_agent.n.02, friend.n.01, fugitive.n.01, gainer.n.01, gainer.n.02, gambler.n.01, gatekeeper.n.01, gatherer.n.01, gemini.n.01, gentile.n.02, good_guy.n.01, good_person.n.01, granter.n.01, greeter.n.01, grinner.n.01, groaner.n.01, grunter.n.01, guesser.n.01, handicapped_person.n.01, hater.n.01, heterosexual.n.01, homosexual.n.01, homunculus.n.02, hope.n.04, hoper.n.01, huddler.n.02, hugger.n.01, immune.n.01, individualist.n.01, inhabitant.n.01, innocent.n.01, insured.n.01, intellectual.n.01, interpreter.n.02, introvert.n.01, jat.n.01, jew.n.01, jewel.n.02, jumper.n.01, junior.n.03, juvenile.n.01, killer.n.01, kink.n.03, kneeler.n.01, knocker.n.02, knower.n.01, large_person.n.01, latin.n.03, laugher.n.01, leader.n.01, learner.n.01, left-hander.n.02, leo.n.01, libra.n.01, life.n.08, lightning_rod.n.01, linguist.n.02, literate.n.01, liver.n.03, longer.n.01, loose_cannon.n.01, loved_one.n.01, lover.n.01, machine.n.02, mailer.n.02, malcontent.n.01, male.n.02, man.n.03, man_jack.n.01, manipulator.n.02, married.n.01, masturbator.n.01, measurer.n.01, mesomorph.n.01, mestizo.n.01, middlebrow.n.01, miracle_man.n.01, misogamist.n.01, mixed-blood.n.01, modern.n.01, money_handler.n.01, monolingual.n.01, mother_hen.n.01, mouse.n.03, mutilator.n.01, namer.n.01, namesake.n.01, national.n.01, native.n.01, native.n.02, neglecter.n.01, neighbor.n.01, neutral.n.01, nondescript.n.01, nonmember.n.01, nonparticipant.n.01, nonpartisan.n.01, nonperson.n.01, nonreligious_person.n.01, nonresident.n.01, nonsmoker.n.01, nonworker.n.01, nude.n.03, nurser.n.01, occultist.n.01, optimist.n.01, orphan.n.02, ostrich.n.01, ouster.n.01, outcaste.n.01, outdoorsman.n.01, owner.n.02, pamperer.n.01, pansexual.n.01, pardoner.n.01, partner.n.03, party.n.05, passer.n.02, peer.n.01, perceiver.n.01, percher.n.01, person_of_color.n.01, personage.n.01, personification. ...
#
#
# Word: will
# Synonyms: volition, will
# Antonyms:
# Hypernyms: faculty.n.01
# Hyponyms: velleity.n.02
#
#
# Word: head
# Synonyms: head, caput
# Antonyms:
# Hypernyms: external_body_part.n.01
# Hyponyms: human_head.n.01
#
#
# Word: out
# Synonyms: out
# Antonyms:
# Hypernyms: failure.n.01
# Hyponyms: putout.n.01, strikeout.n.01
#
#
# Word: strip
# Synonyms: strip
# Antonyms:
# Hypernyms: part.n.03
# Hyponyms: row.n.03
#
#
# Word: meet
# Synonyms: meet, sports_meeting
# Antonyms:
# Hypernyms: athletic_contest.n.01
# Hyponyms: gymkhana.n.01, race_meeting.n.01, regatta.n.01, swimming_meet.n.01, track_meet.n.01
#
#
# Word: customer
# Synonyms: customer, client
# Antonyms:
# Hypernyms: consumer.n.01
# Hyponyms: buyer.n.01, guest.n.03, patron.n.01, policyholder.n.01, shopper.n.01, spender.n.03, subscriber.n.02, taker.n.01, warrantee.n.02, whoremaster.n.01
#
#
# Word: transaction
# Synonyms: transaction, dealing, dealings
# Antonyms:
# Hypernyms: group_action.n.01
# Hyponyms: affairs.n.02, borrowing.n.02, commerce.n.01, deal.n.01, downtick.n.01, exchange.n.04, operations.n.01, rental.n.02, transfer.n.06, uptick.n.01
#
#
# Word: cash
# Synonyms: cash, hard_cash, hard_currency
# Antonyms:
# Hypernyms: currency.n.01
# Hyponyms: change.n.05, change.n.09, pocket_money.n.01, ready_cash.n.01, small_change.n.01
#
#
# Word: cheque
# Synonyms: check, bank_check, cheque
# Antonyms:
# Hypernyms: draft.n.01
# Hyponyms: bad_check.n.01, blank_check.n.02, cashier's_check.n.01, certified_check.n.01, counter_check.n.01, giro.n.01, kite.n.01, kite.n.02, medicare_check.n.01, paycheck.n.01, personal_check.n.01
#
#
# Word: nearly
# Synonyms: about, almost, most, nearly, near, nigh, virtually, well-nigh
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: useless
# Synonyms: useless
# Antonyms: useful
# Hypernyms:
# Hyponyms:
#
#
# Word: village
# Synonyms: village, small_town, settlement
# Antonyms:
# Hypernyms: community.n.01
# Hyponyms: moshav.n.01
#
#
# Word: bank
# Synonyms: bank
# Antonyms:
# Hypernyms: slope.n.01
# Hyponyms: riverbank.n.01, waterside.n.01
#
#
# Word: credit
# Synonyms: recognition, credit
# Antonyms:
# Hypernyms: approval.n.04
# Hyponyms: memorial.n.01, ovation.n.01, salute.n.01
#
#
# Word: stranger
# Synonyms: stranger, alien, unknown
# Antonyms: acquaintance
# Hypernyms: intruder.n.01
# Hyponyms: foreigner.n.02
#
#
# Word: foolhardy
# Synonyms: foolhardy, heady, rash, reckless
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: grip
# Synonyms: clasp, clench, clutch, clutches, grasp, grip, hold
# Antonyms:
# Hypernyms: grasping.n.02
# Hyponyms: chokehold.n.02, embrace.n.01, wrestling_hold.n.01
#
#
# Word: snowmobile
# Synonyms: snowmobile
# Antonyms:
# Hypernyms: tracked_vehicle.n.01
# Hyponyms: sno-cat.n.01
#
#
# Word: major
# Synonyms: major
# Antonyms:
# Hypernyms: commissioned_military_officer.n.01
# Hyponyms:
#
#
# Word: mode
# Synonyms: manner, mode, style, way, fashion
# Antonyms:
# Hypernyms: property.n.02
# Hyponyms: artistic_style.n.01, drape.n.02, fit.n.03, form.n.11, life_style.n.01, response.n.07, setup.n.02, touch.n.04, wise.n.01
#
#
# Word: largest
# Synonyms: large, big
# Antonyms: small, little
# Hypernyms:
# Hyponyms:
#
#
# Word: place
# Synonyms: topographic_point, place, spot
# Antonyms:
# Hypernyms: point.n.02
# Hyponyms: birthplace.n.01, end.n.10, grave.n.02, hiding_place.n.01, high.n.05, hole-in-the-wall.n.01, holy_place.n.01, junction.n.01, mecca.n.02, nesting_place.n.01, overlook.n.01, peak.n.04, polling_place.n.01, pool.n.08, rendezvous.n.02, scour.n.01, service_area.n.01, showplace.n.01, solitude.n.03, stop.n.05, target.n.03, zone.n.01
#
#
# Word: vehicle
# Synonyms: vehicle
# Antonyms:
# Hypernyms: conveyance.n.03
# Hyponyms: bumper_car.n.01, craft.n.02, military_vehicle.n.01, rocket.n.01, skibob.n.01, sled.n.01, steamroller.n.02, wheeled_vehicle.n.01
#
#
# Word: left
# Synonyms: left
# Antonyms: right
# Hypernyms: position.n.01
# Hyponyms: stage_left.n.01
#
#
# Word: running
# Synonyms: run, running, running_play, running_game
# Antonyms:
# Hypernyms: football_play.n.01
# Hyponyms: draw.n.07, end_run.n.01, return.n.12, reverse.n.05, rush.n.07
#
#
# Word: hour
# Synonyms: hour, hr, 60_minutes
# Antonyms:
# Hypernyms: time_unit.n.01
# Hyponyms: man_hour.n.01, sidereal_hour.n.01
#
#
# Word: allowed
# Synonyms: let, allow, permit
# Antonyms: prevent
# Hypernyms:
# Hyponyms: pass.v.17
#
#
# Word: restart
# Synonyms: restart, re-start
# Antonyms:
# Hypernyms: start.v.08
# Hyponyms:
#
#
# Word: balky
# Synonyms: balking, balky
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: resident
# Synonyms: resident, occupant, occupier
# Antonyms: nonresident
# Hypernyms: inhabitant.n.01
# Hyponyms: alexandrian.n.01, coaster.n.01, colonial.n.01, dalesman.n.01, housemate.n.01, inmate.n.01, metropolitan.n.02, outlier.n.01, owner-occupier.n.01, sojourner.n.01, stater.n.02, suburbanite.n.01, tenant.n.03, townsman.n.02
#
#
# Word: enjoy
# Synonyms: enjoy, bask, relish, savor, savour
# Antonyms:
# Hypernyms:
# Hyponyms: devour.v.02, feast_one's_eyes.v.01
#
#
# Word: month
# Synonyms: calendar_month, month
# Antonyms:
# Hypernyms: time_period.n.01
# Hyponyms: date.n.06, gregorian_calendar_month.n.01, hindu_calendar_month.n.01, islamic_calendar_month.n.01, jewish_calendar_month.n.01, revolutionary_calendar_month.n.01
#
#
# Word: brings
# Synonyms: bring, convey, take
# Antonyms:
# Hypernyms: transport.v.02
# Hyponyms: ferry.v.01, fetch.v.03, impart.v.03, land.v.04, return.v.05, transit.v.04, tube.v.02, whisk.v.01
#
#
# Word: activity
# Synonyms: activity
# Antonyms: inactivity
# Hypernyms: act.n.02
# Hyponyms: acting.n.01, aid.n.02, attempt.n.01, behavior.n.01, behavior.n.04, burst.n.03, buzz.n.02, calibration.n.01, ceremony.n.02, ceremony.n.03, concealment.n.03, continuance.n.01, control.n.05, creation.n.01, cup_of_tea.n.01, demand.n.04, dismantling.n.01, diversion.n.01, domesticity.n.02, education.n.01, energizing.n.01, enjoyment.n.02, follow-up.n.02, fun.n.03, game.n.01, grouping.n.02, lamentation.n.02, last.n.03, laughter.n.02, leadership.n.01, liveliness.n.01, market.n.01, measurement.n.01, music.n.03, mystification.n.03, negotiation.n.02, occupation.n.01, occupation.n.03, operation.n.03, operation.n.05, operation.n.11, organization.n.06, perturbation.n.03, placement.n.03, pleasure.n.04, politics.n.05, practice.n.01, precession.n.02, preparation.n.01, procedure.n.01, protection.n.01, provision.n.02, puncture.n.03, release.n.09, representation.n.10, role.n.04, search.n.01, sensory_activity.n.01, service.n.11, sin.n.06, solo.n.01, space_walk.n.01, support.n.01, support.n.08, timekeeping.n.01, training.n.01, turn.n.03, use.n.01, variation.n.02, verbalization.n.02, waste.n.02, work.n.01, works.n.03, worship.n.01, writing.n.05, wrongdoing.n.02
#
#
# Word: motor
# Synonyms: motor
# Antonyms:
# Hypernyms: machine.n.01
# Hyponyms: electric_motor.n.01, engine.n.01, stepper.n.02
#
#
# Word: stored
# Synonyms: store, hive_away, lay_in, put_in, salt_away, stack_away, stash_away
# Antonyms:
# Hypernyms: keep.v.03
# Hyponyms: bin.v.01, computerize.v.02, hive.v.01, roll_up.v.02, victual.v.02
#
#
# Word: garden
# Synonyms: garden
# Antonyms:
# Hypernyms: plot.n.02
# Hyponyms: flower_garden.n.01, formal_garden.n.01, grove.n.02, herb_garden.n.01, hop_garden.n.01, kitchen_garden.n.01, landscaping.n.02, market_garden.n.01, pot_farm.n.01, rock_garden.n.01, roof_garden.n.01, rose_garden.n.01, sunken_garden.n.01, tea_garden.n.01, topiary.n.01
#
#
# Word: chair
# Synonyms: chair
# Antonyms:
# Hypernyms: seat.n.03
# Hyponyms: armchair.n.01, barber_chair.n.01, chair_of_state.n.01, chaise_longue.n.01, eames_chair.n.01, fighting_chair.n.01, folding_chair.n.01, highchair.n.01, ladder-back.n.01, lawn_chair.n.01, rocking_chair.n.01, straight_chair.n.01, swivel_chair.n.01, tablet-armed_chair.n.01, wheelchair.n.01
#
#
# Word: tuned
# Synonyms: tune, tune_up
# Antonyms:
# Hypernyms: adjust.v.01
# Hyponyms: fine-tune.v.02, service.v.02, tune_in.v.01
#
#
# Word: shack
# Synonyms: hovel, hut, hutch, shack, shanty
# Antonyms:
# Hypernyms: shelter.n.01
# Hyponyms: igloo.n.01, mudhif.n.01
#
#
# Word: towed
# Synonyms: tow
# Antonyms:
# Hypernyms: shlep.v.02
# Hyponyms: tug.v.03
#
#
# Word: river
# Synonyms: river
# Antonyms:
# Hypernyms: stream.n.01
# Hyponyms:
#
#
# Word: blade
# Synonyms: blade, leaf_blade
# Antonyms:
# Hypernyms: leaf.n.01
# Hyponyms:
#
#
# Word: powered
# Synonyms: power
# Antonyms:
# Hypernyms: provide.v.02
# Hyponyms: drive.v.20
#
#
# Word: auger
# Synonyms: plumber's_snake, auger
# Antonyms:
# Hypernyms: hand_tool.n.01, snake.n.05
# Hyponyms:
#
#
# Word: sharpened
# Synonyms: sharpen
# Antonyms: dull
# Hypernyms: change.v.01
# Hyponyms: edge.v.04, hone.v.01, strap.v.03, strop.v.01, whet.v.02
#
#
# Word: flock
# Synonyms: flock
# Antonyms:
# Hypernyms: congregation.n.01
# Hyponyms:
#
#
# Word: favorite
# Synonyms: favorite, favourite
# Antonyms:
# Hypernyms: choice.n.01
# Hyponyms:
#
#
# Word: spot
# Synonyms: topographic_point, place, spot
# Antonyms:
# Hypernyms: point.n.02
# Hyponyms: birthplace.n.01, end.n.10, grave.n.02, hiding_place.n.01, high.n.05, hole-in-the-wall.n.01, holy_place.n.01, junction.n.01, mecca.n.02, nesting_place.n.01, overlook.n.01, peak.n.04, polling_place.n.01, pool.n.08, rendezvous.n.02, scour.n.01, service_area.n.01, showplace.n.01, solitude.n.03, stop.n.05, target.n.03, zone.n.01
#
#
# Word: drill
# Synonyms: drill
# Antonyms:
# Hypernyms: tool.n.01
# Hyponyms: auger.n.02, bore_bit.n.01, brace_and_bit.n.01, breast_drill.n.01, core_drill.n.01, dentist's_drill.n.01, hand_drill.n.01, power_drill.n.01, reamer.n.02, trepan.n.02
#
#
# Word: comfort
# Synonyms: comfort, comfortableness
# Antonyms: discomfort
# Hypernyms: condition.n.01
# Hyponyms: convenience.n.01, coziness.n.01, relief.n.02, solace.n.02
#
#
# Word: stove
# Synonyms: stove, kitchen_stove, range, kitchen_range, cooking_stove
# Antonyms:
# Hypernyms: kitchen_appliance.n.01
# Hyponyms: charcoal_burner.n.02, cookstove.n.01, electric_range.n.01, gas_range.n.01, potbelly.n.02, primus_stove.n.01, spirit_stove.n.01
#
#
# Word: glowing
# Synonyms: radiance, glow, glowing
# Antonyms:
# Hypernyms: light.n.01
# Hyponyms: aureole.n.01
#
#
# Word: huddled
# Synonyms: huddle, huddle_together
# Antonyms:
# Hypernyms: cluster.v.01
# Hyponyms:
#
#
# Word: lee
# Synonyms: Lee, Spike_Lee, Shelton_Jackson_Lee
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: normally
# Synonyms: normally, usually, unremarkably, commonly, ordinarily
# Antonyms: remarkably
# Hypernyms:
# Hyponyms:
#
#
# Word: catch
# Synonyms: catch, gimmick
# Antonyms:
# Hypernyms: drawback.n.01
# Hyponyms:
#
#
# Word: whitefish
# Synonyms: whitefish
# Antonyms:
# Hypernyms: seafood.n.01
# Hyponyms:
#
#
# Word: perch
# Synonyms: perch
# Antonyms:
# Hypernyms: support.n.10
# Hyponyms: roost.n.02
#
#
# Word: burbot
# Synonyms: burbot, eelpout, ling, cusk, Lota_lota
# Antonyms:
# Hypernyms: cod.n.03
# Hyponyms:
#
#
# Word: catfish
# Synonyms: catfish, mudcat
# Antonyms:
# Hypernyms: freshwater_fish.n.01
# Hyponyms:
#
#
# Word: bass
# Synonyms: bass
# Antonyms:
# Hypernyms: pitch.n.01
# Hyponyms:
#
#
# Word: plentiful
# Synonyms: plentiful
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: popular
# Synonyms: popular
# Antonyms: unpopular
# Hypernyms:
# Hyponyms:
#
#
# Word: bait
# Synonyms: bait, come-on, hook, lure, sweetener
# Antonyms:
# Hypernyms: temptation.n.01
# Hyponyms:
#
#
# Word: minnow
# Synonyms: minnow, Phoxinus_phoxinus
# Antonyms:
# Hypernyms: cyprinid.n.01
# Hyponyms:
#
#
# Word: use
# Synonyms: use, usage, utilization, utilisation, employment, exercise
# Antonyms:
# Hypernyms: activity.n.01
# Hyponyms: application.n.01, exploitation.n.01, misuse.n.01, play.n.06, practice.n.04, recycling.n.01
#
#
# Word: net
# Synonyms: internet, net, cyberspace
# Antonyms:
# Hypernyms: computer_network.n.01
# Hyponyms:
#
#
# Word: bag
# Synonyms: bag
# Antonyms:
# Hypernyms: container.n.01
# Hyponyms: air_bag.n.01, backpack.n.01, beanbag.n.01, bladder.n.02, body_bag.n.01, book_bag.n.01, burn_bag.n.01, carryall.n.01, drawstring_bag.n.01, dust_bag.n.01, envelope.n.06, gamebag.n.01, golf_bag.n.01, gunnysack.n.01, ice_pack.n.01, mailbag.n.02, nosebag.n.01, pannier.n.01, plastic_bag.n.01, pouch.n.01, purse.n.03, ragbag.n.02, rosin_bag.n.01, sachet.n.01, sack.n.01, saddlebag.n.01, sandbag.n.01, schoolbag.n.01, shopping_bag.n.01, sick_bag.n.01, skin.n.06, sleeping_bag.n.01, sweat_bag.n.01, tea_bag.n.02, toilet_bag.n.01, tool_bag.n.01, tucker-bag.n.01
#
#
# Word: egg
# Synonyms: egg
# Antonyms:
# Hypernyms: ovum.n.01
# Hyponyms: nit.n.02, roe.n.02, roe.n.04, silkworm_seed.n.01, spawn.n.01
#
#
# Word: metal
# Synonyms: metallic_element, metal
# Antonyms:
# Hypernyms: chemical_element.n.01
# Hyponyms: alkali_metal.n.01, alkaline_earth.n.01, aluminum.n.01, americium.n.01, antimony.n.01, barium.n.01, base_metal.n.01, berkelium.n.01, beryllium.n.01, bismuth.n.01, cadmium.n.01, calcium.n.01, californium.n.01, cerium.n.01, cesium.n.01, chromium.n.01, cobalt.n.01, copper.n.01, curium.n.01, dysprosium.n.01, einsteinium.n.01, erbium.n.01, europium.n.01, fermium.n.01, francium.n.01, gadolinium.n.01, gallium.n.01, hafnium.n.01, heavy_metal.n.01, holmium.n.01, indium.n.01, iridium.n.01, iron.n.01, lanthanum.n.01, lead.n.02, lithium.n.01, lutetium.n.01, magnesium.n.01, manganese.n.01, mercury.n.01, molybdenum.n.01, neodymium.n.01, neptunium.n.01, nickel.n.01, niobium.n.01, noble_metal.n.01, osmium.n.01, palladium.n.01, polonium.n.01, potassium.n.01, praseodymium.n.01, promethium.n.01, protactinium.n.01, radium.n.01, rhenium.n.01, rhodium.n.01, rubidium.n.01, ruthenium.n.01, samarium.n.01, scandium.n.01, sodium.n.01, strontium.n.01, tantalum.n.01, technetium.n.01, terbium.n.01, thallium.n.01, thorium.n.01, thulium.n.01, tin.n.01, titanium.n.01, tungsten.n.01, uranium.n.01, vanadium.n.01, ytterbium.n.01, yttrium.n.01, zinc.n.01, zirconium.n.01
#
#
# Word: spoon
# Synonyms: spoon
# Antonyms:
# Hypernyms: container.n.01, cutlery.n.02
# Hyponyms: dessert_spoon.n.01, runcible_spoon.n.01, soupspoon.n.01, sugar_spoon.n.01, tablespoon.n.02, tea_maker.n.01, teaspoon.n.02, wooden_spoon.n.02
#
#
# Word: jigging
# Synonyms: jig
# Antonyms:
# Hypernyms: dance.v.02
# Hyponyms:
#
#
# Word: lure
# Synonyms: lure, enticement, come-on
# Antonyms:
# Hypernyms: attraction.n.03
# Hyponyms:
#
#
# Word: just
# Synonyms: just
# Antonyms: unjust
# Hypernyms:
# Hyponyms:
#
#
# Word: hook
# Synonyms: hook
# Antonyms:
# Hypernyms: catch.n.07
# Hyponyms:
#
#
# Word: best
# Synonyms: best
# Antonyms: worst
# Hypernyms: attempt.n.01
# Hyponyms:
#
#
# Word: whatever
# Synonyms: any, whatever, whatsoever
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: taking
# Synonyms: pickings, taking
# Antonyms:
# Hypernyms: action.n.01
# Hyponyms:
#
#
# Word: time
# Synonyms: time, clip
# Antonyms:
# Hypernyms: case.n.01
# Hyponyms:
#
#
# Word: hunting
# Synonyms: hunt, hunting
# Antonyms:
# Hypernyms: blood_sport.n.01, outdoor_sport.n.01
# Hyponyms: battue.n.01, beagling.n.01, coursing.n.01, deer_hunting.n.01, ducking.n.01, fox_hunting.n.01, pigsticking.n.01
#
#
# Word: sport
# Synonyms: sport, athletics
# Antonyms:
# Hypernyms: diversion.n.01
# Hyponyms: archery.n.01, athletic_game.n.01, blood_sport.n.01, contact_sport.n.01, cycling.n.01, funambulism.n.01, gymnastics.n.01, judo.n.01, outdoor_sport.n.01, racing.n.01, riding.n.01, rock_climbing.n.01, rowing.n.01, skating.n.01, skiing.n.01, sledding.n.01, spectator_sport.n.01, team_sport.n.01, track_and_field.n.01, water_sport.n.01
#
#
# Word: colder
# Synonyms: cold
# Antonyms: hot
# Hypernyms:
# Hyponyms:
#
#
# Word: weather
# Synonyms: weather, weather_condition, conditions, atmospheric_condition
# Antonyms:
# Hypernyms: atmospheric_phenomenon.n.01
# Hyponyms: atmosphere.n.04, bad_weather.n.01, cold_weather.n.01, elements.n.01, fair_weather.n.01, good_weather.n.01, hot_weather.n.01, precipitation.n.03, thaw.n.02, wave.n.08, wind.n.01
#
#
# Word: move
# Synonyms: move
# Antonyms:
# Hypernyms: decision.n.01
# Hyponyms: demarche.n.01, maneuver.n.04
#
#
# Word: warmth
# Synonyms: heat, warmth
# Antonyms:
# Hypernyms: temperature.n.02
# Hyponyms:
#
#
# Word: hunter
# Synonyms: hunter, huntsman
# Antonyms:
# Hypernyms: skilled_worker.n.01
# Hyponyms: bounty_hunter.n.02, courser.n.01, deer_hunter.n.01, duck_hunter.n.01, falconer.n.01, fowler.n.02, huntress.n.01, lion-hunter.n.02, pothunter.n.03, snarer.n.01, stalker.n.02, tracker.n.01, trapper.n.01
#
#
# Word: face
# Synonyms: face, human_face
# Antonyms:
# Hypernyms: external_body_part.n.01
# Hyponyms: countenance.n.03
#
#
# Word: similar
# Synonyms: similar
# Antonyms: dissimilar
# Hypernyms:
# Hyponyms:
#
#
# Word: extreme
# Synonyms: extreme
# Antonyms:
# Hypernyms: degree.n.01
# Hyponyms:
#
#
# Word: require
# Synonyms: necessitate, ask, postulate, need, require, take, involve, call_for, demand
# Antonyms: obviate
# Hypernyms:
# Hyponyms: claim.v.05, compel.v.02, cost.v.02, cry_out_for.v.01, draw.v.22, govern.v.04
#
#
# Word: kept
# Synonyms: keep, maintain, hold
# Antonyms:
# Hypernyms:
# Hyponyms: conserve.v.01, continue.v.03, distance.v.01, hold_over.v.03, housekeep.v.01, preserve.v.06, pressurize.v.02
#
#
# Word: top
# Synonyms: top
# Antonyms:
# Hypernyms: region.n.01
# Hyponyms: capital.n.08, crown.n.02, crown.n.07, head.n.07, masthead.n.03
#
#
# Word: started
# Synonyms: get_down, begin, get, start_out, start, set_about, set_out, commence
# Antonyms: end
# Hypernyms:
# Hyponyms: attack.v.05, auspicate.v.02, break_in.v.03, come_on.v.05, embark.v.02, fall.v.30, get_cracking.v.01, get_to.v.02, jump_off.v.01, plunge.v.04, recommence.v.02, strike_out.v.06
#
#
# Word: dependable
# Synonyms: reliable, dependable
# Antonyms: unreliable, undependable
# Hypernyms:
# Hyponyms:
#
#
# Word: death
# Synonyms: death, decease, expiry
# Antonyms: birth
# Hypernyms: change.n.01
# Hyponyms: fatality.n.01, martyrdom.n.01, megadeath.n.01, passing.n.02, wrongful_death.n.01
#
#
# Word: situation
# Synonyms: situation, state_of_affairs
# Antonyms:
# Hypernyms: state.n.02
# Hyponyms: absurd.n.01, acceptance.n.03, ballgame.n.01, challenge.n.01, childlessness.n.01, complication.n.02, crowding.n.01, disequilibrium.n.01, element.n.06, environment.n.01, equilibrium.n.01, exclusion.n.01, goldfish_bowl.n.01, hotbed.n.01, inclusion.n.01, intestacy.n.01, picture.n.04, prison.n.02, rejection.n.02, size.n.04, square_one.n.01, status_quo.n.01, thing.n.01
#
#
# Word: develop
# Synonyms: develop
# Antonyms:
# Hypernyms: create.v.02
# Hyponyms: build.v.06
#
#
# Word: machine
# Synonyms: machine
# Antonyms:
# Hypernyms: device.n.01
# Hyponyms: assembly.n.01, bagger.n.02, calculator.n.02, calender.n.01, cash_machine.n.01, comber.n.03, computer.n.01, concrete_mixer.n.01, corker.n.02, cotton_gin.n.01, decoder.n.02, farm_machine.n.01, franking_machine.n.01, hop-picker.n.01, machine_tool.n.01, machinery.n.01, milking_machine.n.01, motor.n.01, pavior.n.01, perpetual_motion_machine.n.01, pile_driver.n.01, power_shovel.n.01, power_tool.n.01, press.n.03, press.n.07, printer.n.03, record_player.n.01, riveting_machine.n.01, self-feeder.n.01, simulator.n.01, slicer.n.02, slot_machine.n.01, snow_thrower.n.01, sorter.n.02, stamp.n.07, staple_gun.n.01, stapler.n.01, textile_machine.n.01, time_machine.n.01, trimmer.n.02, workhorse.n.01, zamboni.n.01
#
#
# Word: break
# Synonyms: interruption, break
# Antonyms:
# Hypernyms: happening.n.01
# Hyponyms: dislocation.n.01, eclipse.n.01, punctuation.n.01, suspension.n.04
#
#
# Word: while
# Synonyms: while, piece, spell, patch
# Antonyms:
# Hypernyms: time.n.03
# Hyponyms: cold_spell.n.01, hot_spell.n.01, snap.n.02
#
#
# Word: mile
# Synonyms: mile, statute_mile, stat_mi, land_mile, international_mile, mi
# Antonyms:
# Hypernyms: linear_unit.n.01
# Hyponyms:
#
#
# Word: rifle
# Synonyms: rifle
# Antonyms:
# Hypernyms: firearm.n.01
# Hyponyms: carbine.n.01, garand_rifle.n.01, sniper_rifle.n.01, winchester.n.02
#
#
# Word: care
# Synonyms: care, attention, aid, tending
# Antonyms:
# Hypernyms: work.n.01
# Hyponyms: babysitting.n.01, dental_care.n.01, faith_healing.n.01, first_aid.n.01, hair_care.n.01, healthcare.n.01, incubation.n.01, livery.n.03, manicure.n.01, maternalism.n.02, nourishment.n.02, nursing.n.01, nurturance.n.01, pedicure.n.01, personal_care.n.01, pet_sitting.n.01, skin_care.n.01, tender_loving_care.n.01, treatment.n.01, tree_surgery.n.01
#
#
# Word: bolt
# Synonyms: thunderbolt, bolt, bolt_of_lightning
# Antonyms:
# Hypernyms: lightning.n.01
# Hyponyms:
#
#
# Word: grease
# Synonyms: grease, lubricating_oil
# Antonyms:
# Hypernyms: oil.n.01
# Hyponyms: axle_grease.n.01
#
#
# Word: freeze
# Synonyms: freeze, freezing
# Antonyms:
# Hypernyms: cooling.n.01, phase_change.n.01
# Hyponyms: freeze-drying.n.01, frost.n.03
#
#
# Word: solid
# Synonyms: solid
# Antonyms:
# Hypernyms: matter.n.03
# Hyponyms: crystal.n.01, dry_ice.n.01, food.n.02, glass.n.01, plastic.n.01, powder.n.01, precipitate.n.01, vitrification.n.01
#
#
# Word: firing
# Synonyms: fire, firing
# Antonyms:
# Hypernyms: attack.n.01
# Hyponyms: antiaircraft_fire.n.01, artillery_fire.n.01, barrage.n.02, broadside.n.05, call_fire.n.01, concentrated_fire.n.01, counterfire.n.01, counterpreparation_fire.n.01, cover.n.07, crossfire.n.02, destruction_fire.n.01, direct_fire.n.01, distributed_fire.n.01, friendly_fire.n.01, fusillade.n.01, grazing_fire.n.01, harassing_fire.n.01, hostile_fire.n.01, indirect_fire.n.01, interdiction_fire.n.01, neutralization_fire.n.01, observed_fire.n.01, preparation_fire.n.01, radar_fire.n.01, registration_fire.n.01, scheduled_fire.n.01, searching_fire.n.01, supporting_fire.n.01, suppressive_fire.n.01, unobserved_fire.n.01
#
#
# Word: pin
# Synonyms: pin
# Antonyms:
# Hypernyms: jewelry.n.01
# Hyponyms: brooch.n.01, scatter_pin.n.01, stickpin.n.01, tie_tack.n.01
#
#
# Word: struck
# Synonyms: strike
# Antonyms:
# Hypernyms: touch.v.01
# Hyponyms: beat.v.03, beat.v.11, buffet.v.01, butt.v.02, chop.v.04, clout.v.01, dab.v.02, down.v.05, hew.v.02, jab.v.02, knock.v.01, peck.v.01, rap.v.01, sclaff.v.01, sclaff.v.02, sideswipe.v.01, slap.v.01, spur.v.03, tap.v.03, whip.v.04
#
#
# Word: hammer
# Synonyms: hammer, cock
# Antonyms:
# Hypernyms: striker.n.05
# Hyponyms:
#
#
# Word: bear
# Synonyms: bear
# Antonyms:
# Hypernyms: carnivore.n.01
# Hyponyms: american_black_bear.n.01, asiatic_black_bear.n.01, bear_cub.n.01, brown_bear.n.01, bruin.n.01, ice_bear.n.01, sloth_bear.n.01
#
#
# Word: lived
# Synonyms: populate, dwell, live, inhabit
# Antonyms:
# Hypernyms: be.v.03
# Hyponyms: board.v.02, camp.v.01, cohabit.v.01, lodge.v.01, neighbor.v.01, nest.v.01, occupy.v.02, overpopulate.v.01, people.v.02, reside.v.01, tenant.v.01
#
#
# Word: weapon
# Synonyms: weapon, arm, weapon_system
# Antonyms:
# Hypernyms: instrument.n.01
# Hyponyms: bow.n.04, bow_and_arrow.n.01, brass_knucks.n.01, fire_ship.n.01, flamethrower.n.01, greek_fire.n.01, gun.n.01, knife.n.02, light_arm.n.01, missile.n.01, pike.n.04, projectile.n.01, slasher.n.02, sling.n.04, spear.n.01, stun_gun.n.01, sword.n.01, tomahawk.n.01, weapon_of_mass_destruction.n.01
#
#
# Word: failed
# Synonyms: fail, neglect
# Antonyms:
# Hypernyms:
# Hyponyms: choke.v.06, default.v.01, lose_track.v.01, miss.v.03, muff.v.01, strike_out.v.02
#
#
# Word: operate
# Synonyms: operate, run
# Antonyms:
# Hypernyms: direct.v.04
# Hyponyms: block.v.05, financier.v.01, warm_up.v.01, work.v.16
#
#
# Word: other
# Synonyms: other
# Antonyms: same
# Hypernyms:
# Hyponyms:
#
#
# Word: outdoor
# Synonyms: outdoor, out-of-door, outside
# Antonyms: indoor
# Hypernyms:
# Hyponyms:
#
#
# Word: include
# Synonyms: include
# Antonyms: exclude
# Hypernyms:
# Hyponyms: embrace.v.01, hold.v.11, incorporate.v.02, inhere_in.v.01, involve.v.05, subsume.v.01
#
#
# Word: cross
# Synonyms: cross
# Antonyms:
# Hypernyms: structure.n.01
# Hyponyms:
#
#
# Word: country
# Synonyms: state, nation, country, land, commonwealth, res_publica, body_politic
# Antonyms:
# Hypernyms: political_unit.n.01
# Hyponyms: ally.n.01, city_state.n.01, commonwealth_country.n.01, developing_country.n.01, dominion.n.03, foreign_country.n.01, reich.n.01, rogue_state.n.01, sea_power.n.02, suzerain.n.01, world_power.n.01
#
#
# Word: skiing
# Synonyms: skiing
# Antonyms:
# Hypernyms: sport.n.01
# Hyponyms: cross-country_skiing.n.01, ski_jumping.n.01
#
#
# Word: snowmobiling
# Synonyms: snowmobile
# Antonyms:
# Hypernyms: ride.v.02
# Hyponyms:
#
#
# Word: racing
# Synonyms: racing
# Antonyms:
# Hypernyms: sport.n.01
# Hyponyms: auto_racing.n.01, boat_racing.n.01, camel_racing.n.01, greyhound_racing.n.01, horse_racing.n.01
#
#
# Word: team
# Synonyms: team, squad
# Antonyms:
# Hypernyms: unit.n.03
# Hyponyms: a-team.n.01, baseball_team.n.01, basketball_team.n.01, battery.n.04, crew.n.04, defense.n.03, flying_squad.n.01, football_team.n.01, hit_squad.n.01, hockey_team.n.01, junior_varsity.n.01, little-league_team.n.01, major-league_team.n.01, minor-league_team.n.01, offense.n.04, police_squad.n.01, powerhouse.n.02, second_string.n.01, section.n.05, varsity.n.02
#
#
# Word: included
# Synonyms: include
# Antonyms: exclude
# Hypernyms:
# ...
#
#
# Word: employment
# Synonyms: employment, employ
# Antonyms: unemployment
# Hypernyms: state.n.02
# Hyponyms:
#
#
# Word: reason
# Synonyms: reason, ground
# Antonyms:
# Hypernyms: rational_motive.n.01
# Hyponyms: occasion.n.03, score.n.05, why.n.01
#
#
# Word: transient
# Synonyms: transient
# Antonyms:
# Hypernyms: traveler.n.01
# Hyponyms:
#
#
# Word: following
# Synonyms: following, followers
# Antonyms:
# Hypernyms: multitude.n.03
# Hyponyms: claque.n.01, faithful.n.01, fandom.n.01
#
#
# Word: job
# Synonyms: occupation, business, job, line_of_work, line
# Antonyms:
# Hypernyms: activity.n.01
# Hyponyms: accountancy.n.01, appointment.n.05, career.n.01, catering.n.01, confectionery.n.03, employment.n.02, farming.n.02, game.n.10, metier.n.02, photography.n.03, position.n.06, profession.n.02, sport.n.02, trade.n.02, treadmill.n.03
#
#
# Word: working
# Synonyms: working, workings
# Antonyms:
# Hypernyms: excavation.n.03
# Hyponyms:
#
#
# Word: corporation
# Synonyms: corporation, corp
# Antonyms:
# Hypernyms: firm.n.01
# Hyponyms: boy_scouts_of_america.n.01, closed_corporation.n.01, closely_held_corporation.n.01, conglomerate.n.02, federal_deposit_insurance_corporation.n.01, federal_home_loan_mortgage_corporation.n.01, federal_national_mortgage_association.n.01, large_cap.n.01, shell_corporation.n.01, small_cap.n.01
#
#
# Word: transferred
# Synonyms: transfer, reassign
# Antonyms:
# Hypernyms: delegate.v.02
# Hyponyms: exchange.v.04, second.v.02
#
#
# Word: requirement
# Synonyms: requirement, demand
# Antonyms:
# Hypernyms: duty.n.01
# Hyponyms:
#
#
# Word: definitely
# Synonyms: decidedly, unquestionably, emphatically, definitely, in_spades, by_all_odds
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: endure
# Synonyms: digest, endure, stick_out, stomach, bear, stand, tolerate, support, brook, abide, suffer, put_up
# Antonyms:
# Hypernyms: permit.v.01
# Hyponyms: accept.v.07, bear_up.v.01, pay.v.09, sit_out.v.02, stand_for.v.04, take_a_joke.v.01, take_lying_down.v.01
#
#
# Word: involved
# Synonyms: involve, affect, regard
# Antonyms:
# Hypernyms: refer.v.02
# Hyponyms: implicate.v.01
#
#
# Word: give
# Synonyms: give, spring, springiness
# Antonyms:
# Hypernyms: elasticity.n.01
# Hyponyms:
#
#
# Word: such
# Synonyms: such
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: extended
# Synonyms: widen, broaden, extend
# Antonyms:
# Hypernyms: increase.v.02
# Hyponyms: broaden.v.01, globalize.v.01, stretch.v.08, territorialize.v.03
#
#
# Word: wa
# Synonyms: Washington, Evergreen_State, WA
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: adapted
# Synonyms: adapt, accommodate
# Antonyms:
# Hypernyms: change.v.03
# Hyponyms: adjust.v.04, anglicise.v.01, christianize.v.01, domesticate.v.01, domesticate.v.03, electrify.v.03, fit.v.05, gear.v.01, naturalize.v.03, shoehorn.v.01, tailor.v.01, transcribe.v.03
#
#
# Word: way
# Synonyms: manner, mode, style, way, fashion
# Antonyms:
# Hypernyms: property.n.02
# Hyponyms: artistic_style.n.01, drape.n.02, fit.n.03, form.n.11, life_style.n.01, response.n.07, setup.n.02, touch.n.04, wise.n.01
#
#
# Word: owning
# Synonyms: own, have, possess
# Antonyms:
# Hypernyms:
# Hyponyms: prepossess.v.01
#
#
# Word: able
# Synonyms: able
# Antonyms: unable
# Hypernyms:
# Hyponyms:
#
#
# Word: independently
# Synonyms: independently
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: outdoors
# Synonyms: outdoors, out-of-doors, open_air, open
# Antonyms:
# Hypernyms: outside.n.01
# Hyponyms:
#
#
# Word: had
# Synonyms: have, have_got, hold
# Antonyms:
# Hypernyms:
# Hyponyms: bear.v.11, carry.v.21, keep.v.03, keep.v.07, keep.v.19, keep.v.20, monopolize.v.02, stock.v.01, sustain.v.04, wield.v.01
#
#
# Word: learned
# Synonyms: learn, larn, acquire
# Antonyms:
# Hypernyms:
# Hyponyms: absorb.v.02, catch_up.v.02, relearn.v.01, study.v.05
#
#
# Word: adjust
# Synonyms: adjust, set, correct
# Antonyms:
# Hypernyms: change.v.01
# Hyponyms: align.v.04, attune.v.01, calibrate.v.01, citify.v.01, depressurize.v.01, focus.v.05, harmonize.v.05, justify.v.05, linearize.v.01, match.v.05, modulate.v.04, plumb.v.04, pressurize.v.03, proportion.v.02, readjust.v.02, regulate.v.01, set.v.08, synchronize.v.01, temper.v.03, time.v.04, time.v.05, trim.v.09, tune.v.01, tune.v.02, zero.v.01, zero.v.02
#
#
# Word: passed
# Synonyms: pass, go_through, go_across
# Antonyms:
# Hypernyms: travel.v.01
# Hyponyms: break_through.v.01, crash.v.04, cut.v.15, cycle.v.02, fumble.v.02, infiltrate.v.04, lock.v.08, make.v.36, muscle.v.01, negotiate.v.02, run.v.29, squeak_by.v.02, transgress.v.04, transit.v.01, transit.v.02, traverse.v.01
#
#
# Word: adult
# Synonyms: adult, grownup
# Antonyms: juvenile
# Hypernyms: person.n.01
# Hyponyms: brachycephalic.n.01, caregiver.n.02, catch.n.03, centrist.n.01, character.n.05, conservative.n.01, dolichocephalic.n.01, elder.n.01, ex-spouse.n.01, host.n.01, important_person.n.01, jack_of_all_trades.n.01, liberal.n.01, liberal.n.02, man.n.01, militarist.n.01, oldster.n.01, pacifist.n.01, patrician.n.01, pledgee.n.01, pledger.n.01, professional.n.01, sobersides.n.01, sophisticate.n.01, stay-at-home.n.01, stoic.n.02, thoroughbred.n.01, woman.n.01
#
#
# Word: took
# Synonyms: take
# Antonyms:
# Hypernyms: act.v.01
# Hyponyms:
#
#
# Word: stock
# Synonyms: stock
# Antonyms:
# Hypernyms: capital.n.01
# Hyponyms: authorized_shares.n.01, common_stock.n.01, common_stock_equivalent.n.01, control_stock.n.01, float.n.02, growth_stock.n.01, hot_stock.n.01, no-par-value_stock.n.01, preferred_stock.n.01, quarter_stock.n.01, treasury_stock.n.01, voting_stock.n.01, watered_stock.n.01
#
#
# Word: stuck
# Synonyms: lodge, wedge, stick, deposit
# Antonyms: dislodge
# Hypernyms: fasten.v.01
# Hyponyms: redeposit.v.02
#
#
# Word: rut
# Synonyms: rut
# Antonyms:
# Hypernyms: groove.n.01
# Hyponyms:
#
#
# Word: townspeople
# Synonyms: town, townspeople, townsfolk
# Antonyms:
# Hypernyms: municipality.n.02
# Hyponyms: borough.n.02
#
#
# Word: centered
# Synonyms: focus_on, center_on, revolve_around, revolve_about, concentrate_on, center
# Antonyms:
# Hypernyms: refer.v.02
# Hyponyms:
#
#
# Word: post
# Synonyms: post, station
# Antonyms:
# Hypernyms: position.n.01
# Hyponyms: bridgehead.n.02, lookout.n.02, outstation.n.01
#
#
# Word: office
# Synonyms: office, business_office
# Antonyms:
# Hypernyms: place_of_business.n.01
# Hyponyms: box_office.n.02, countinghouse.n.01, government_office.n.01, headquarters.n.01, life_office.n.01, loan_office.n.02, newsroom.n.02, shipping_office.n.01
#
#
# Word: decided
# Synonyms: decide, make_up_one's_mind, determine
# Antonyms:
# Hypernyms:
# Hyponyms: choose.v.01, judge.v.05, measure.v.01, orient.v.02, purpose.v.02, regulate.v.02, rule.v.02, seal.v.03, will.v.02
#
#
# Word: moving
# Synonyms: travel, go, move, locomote
# Antonyms: stay_in_place
# Hypernyms:
# Hyponyms: accompany.v.02, advance.v.01, angle.v.01, ascend.v.01, automobile.v.01, back.v.02, bang.v.04, beetle.v.02, betake_oneself.v.01, billow.v.02, bounce.v.03, breeze.v.02, caravan.v.01, career.v.01, carry.v.36, circle.v.01, circle.v.02, circuit.v.01, circulate.v.07, come.v.01, come.v.11, crawl.v.01, cruise.v.02, derail.v.02, descend.v.01, do.v.13, drag.v.04, draw.v.12, drive.v.02, drive.v.14, ease.v.01, fall.v.01, fall.v.15, ferry.v.03, float.v.01, float.v.02, float.v.05, flock.v.01, fly.v.01, fly.v.06, follow.v.01, follow.v.04, forge.v.05, get_around.v.04, ghost.v.01, glide.v.01, go_around.v.02, hiss.v.02, hurtle.v.01, island_hop.v.01, lance.v.01, lurch.v.03, outflank.v.01, pace.v.02, pan.v.01, pass.v.01, pass_over.v.04, play.v.09, plow.v.03, prance.v.02, precede.v.04, precess.v.01, proceed.v.02, propagate.v.02, pursue.v.02, push.v.09, raft.v.02, repair.v.03, retreat.v.02, retrograde.v.02, return.v.01, ride.v.01, ride.v.04, ride.v.10, rise.v.01, roll.v.12, round.v.01, run.v.11, run.v.34, rush.v.01, scramble.v.01, seek.v.04, shuttle.v.01, sift.v.01, ski.v.01, slice_into.v.01, slither.v.01, snowshoe.v.01, speed.v.04, steamer.v.01, step.v.01, step.v.02, step.v.06, stray.v.02, swap.v.02, swash.v.01, swim.v.01, swim.v.05, swing.v.03, taxi.v.01, trail.v.03, tram.v.01, transfer.v.06, travel.v.04, travel.v.05, travel.v.06, travel_by.v.01, travel_purposefully.v.01, travel_rapidly.v.01, trundle.v.01, turn.v.06, walk.v.01, walk.v.10, weave.v.04, wend.v.01, wheel.v.03, whine.v.01, whish.v.02, whisk.v.02, whistle.v.02, withdraw.v.01, zigzag.v.01, zoom.v.02
#
#
# Word: now
# Synonyms: now
# Antonyms:
# Hypernyms: present.n.01
# Hyponyms:
#
#
# Word: possibly
# Synonyms: possibly, perchance, perhaps, maybe, mayhap, peradventure
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: remaining
# Synonyms: stay, remain, rest
# Antonyms: change
# Hypernyms: be.v.01
# Hyponyms: be.v.12, keep.v.12, keep_out.v.02, sit_tight.v.01, stand.v.07, stick_together.v.01
#
#
# Word: rest
# Synonyms: remainder, balance, residual, residue, residuum, rest
# Antonyms:
# Hypernyms: part.n.01
# Hyponyms: leftover.n.01
#
#
# Word: february
# Synonyms: February, Feb
# Antonyms:
# Hypernyms: gregorian_calendar_month.n.01
# Hyponyms:
#
#
# Word: miss
# Synonyms: girl, miss, missy, young_lady, young_woman, fille
# Antonyms:
# Hypernyms: woman.n.01
# Hyponyms: baby.n.05, belle.n.01, bimbo.n.01, chachka.n.01, chit.n.01, colleen.n.01, dame.n.01, flapper.n.01, gal.n.03, gamine.n.02, gibson_girl.n.01, lass.n.01, maid.n.02, may_queen.n.01, mill-girl.n.01, party_girl.n.01, peri.n.01, ring_girl.n.01, rosebud.n.02, sex_kitten.n.01, shop_girl.n.01, soubrette.n.01, sweater_girl.n.01, tomboy.n.01, valley_girl.n.01, working_girl.n.01
#
#
# Word: delicious
# Synonyms: Delicious
# Antonyms:
# Hypernyms: eating_apple.n.01
# Hyponyms: golden_delicious.n.01, red_delicious.n.01
#
#
# Word: clear
# Synonyms: clear
# Antonyms:
# Hypernyms: innocence.n.03
# Hyponyms:
#
#
# Word: steak
# Synonyms: steak
# Antonyms:
# Hypernyms: cut.n.06
# Hyponyms: beefsteak.n.01, fish_steak.n.01
#
#
# Word: sausage
# Synonyms: sausage
# Antonyms:
# Hypernyms: meat.n.01
# Hyponyms: blood_sausage.n.01, bologna.n.02, chipolata.n.01, chorizo.n.01, frank.n.02, headcheese.n.01, knackwurst.n.01, liver_pudding.n.01, pepperoni.n.01, pork_sausage.n.01, salami.n.01, souse.n.02
#
#
# Word: smoked
# Synonyms: smoke
# Antonyms:
# Hypernyms: consume.v.02
# Hyponyms: chain-smoke.v.01, inhale.v.01, puff.v.01
#
#
# Word: pancake
# Synonyms: pancake, battercake, flannel_cake, flannel-cake, flapcake, flapjack, griddlecake, hotcake, hot_cake
# Antonyms:
# Hypernyms: cake.n.03
# Hyponyms: blini.n.01, blintz.n.01, buckwheat_cake.n.01, buttermilk_pancake.n.01, crape.n.01, pfannkuchen.n.01, potato_pancake.n.01, tortilla.n.01
#
#
# Word: freedom
# Synonyms: freedom
# Antonyms:
# Hypernyms: state.n.02
# Hyponyms: academic_freedom.n.01, civil_liberty.n.01, enfranchisement.n.01, free_hand.n.01, free_rein.n.01, freedom_of_the_seas.n.01, independence.n.01, liberty.n.02, liberty.n.03, svoboda.n.01
#
#
# Word: afforded
# Synonyms: afford
# Antonyms:
# Hypernyms: spend.v.02
# Hyponyms:
#
#
# Word: secluded
# Synonyms: seclude, sequester, sequestrate, withdraw
# Antonyms:
# Hypernyms: isolate.v.01
# Hyponyms:
#
#
# Word: within
# Synonyms: inside, within
# Antonyms: outside
# Hypernyms:
# Hyponyms:
#
#
# Word: superb
# Synonyms: brilliant, superb
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: friendship
# Synonyms: friendship, friendly_relationship
# Antonyms:
# Hypernyms: relationship.n.03
# Hyponyms: blood_brotherhood.n.01, company.n.03, confidence.n.04
#
#
# Word: camaraderie
# Synonyms: chumminess, camaraderie, comradeliness, comradery, comradeship
# Antonyms:
# Hypernyms: sociability.n.01
# Hyponyms:
#
#
# Word: happy
# Synonyms: happy
# Antonyms: unhappy
# Hypernyms:
# Hyponyms:
#
#
# Word: opportunity
# Synonyms: opportunity, chance
# Antonyms:
# Hypernyms: possibility.n.02
# Hyponyms: brass_ring.n.01, day.n.09, fresh_start.n.01, hearing.n.02, hunting_ground.n.01, occasion.n.05, opening.n.06, room.n.03, say.n.01, shot.n.04, street.n.04, throw.n.02
#
#
# Word: approached
# Synonyms: approach, near, come_on, go_up, draw_near, draw_close, come_near
# Antonyms:
# Hypernyms: come.v.01
# Hyponyms: bear_down_on.v.01, close.v.12, drive_up.v.01, edge_in.v.01, push.v.06
#
#
# Word: midpoint
# Synonyms: center, centre, midpoint
# Antonyms:
# Hypernyms: point.n.02
# Hyponyms: bight.n.04, bowels.n.01, bull's_eye.n.02, center_of_curvature.n.01, center_of_gravity.n.01, center_of_mass.n.01, core.n.02, core.n.03, navel.n.02, nombril.n.01, nucleus.n.02, nucleus.n.04
#
#
# Word: wanted
# Synonyms: desire, want
# Antonyms:
# Hypernyms:
# Hyponyms: ambition.v.01, crave.v.01, envy.v.02, fancy.v.02, feel_like.v.01, hanker.v.01, hope.v.02, itch.v.04, like.v.05, lust_after.v.01, miss.v.02, seek.v.01, wish.v.01, wish.v.02, wish.v.04
#
#
# Word: supermarket
# Synonyms: supermarket
# Antonyms:
# Hypernyms: grocery_store.n.01
# Hyponyms: hypermarket.n.01
#
#
# Word: mall
# Synonyms: promenade, mall
# Antonyms:
# Hypernyms: walk.n.05
# Hyponyms: esplanade.n.01
#
#
# Word: fancy
# Synonyms: illusion, fantasy, phantasy, fancy
# Antonyms:
# Hypernyms: misconception.n.01
# Hyponyms: bubble.n.03, will-o'-the-wisp.n.02, wishful_thinking.n.01
#
#
# Word: restaurant
# Synonyms: restaurant, eating_house, eating_place, eatery
# Antonyms:
# Hypernyms: building.n.01
# Hyponyms: bistro.n.01, brasserie.n.01, brewpub.n.01, cafe.n.01, cafeteria.n.01, canteen.n.03, canteen.n.05, diner.n.03, greasy_spoon.n.01, grillroom.n.01, hash_house.n.01, lunchroom.n.01, rotisserie.n.02, steakhouse.n.01, teashop.n.01
#
#
# Word: gourmet
# Synonyms: epicure, gourmet, gastronome, bon_vivant, epicurean, foodie
# Antonyms:
# Hypernyms: sensualist.n.01
# Hyponyms:
#
#
# Word: closer
# Synonyms: closer
# Antonyms:
# Hypernyms: person.n.01
# Hyponyms:
#
#
# Word: drive
# Synonyms: drive, thrust, driving_force
# Antonyms:
# Hypernyms: propulsion.n.02
# Hyponyms: firewall.n.01, impulse.n.05
#
#
# Word: returned
# Synonyms: return
# Antonyms:
# Hypernyms: travel.v.01
# Hyponyms: backtrack.v.01, boomerang.v.01, bounce.v.04, cut_back.v.01, go_home.v.01, home.v.02, resurrect.v.03, return.v.14, revisit.v.01, trace.v.03
#
#
# Word: old
# Synonyms: old
# Antonyms:
# Hypernyms: past.n.01
# Hyponyms:
#
#
# Word: store
# Synonyms: shop, store
# Antonyms:
# Hypernyms: mercantile_establishment.n.01
# Hyponyms: bakery.n.01, barbershop.n.01, bazaar.n.01, betting_shop.n.01, bodega.n.01, bookshop.n.01, booth.n.04, boutique.n.01, building_supply_store.n.01, butcher_shop.n.01, canteen.n.02, chain_store.n.01, cleaners.n.01, clothing_store.n.01, commissary.n.01, computer_store.n.01, confectionery.n.02, convenience_store.n.01, delicatessen.n.02, drugstore.n.01, florist.n.02, gift_shop.n.01, hardware_store.n.01, head_shop.n.01, junk_shop.n.01, millinery.n.01, outfitter.n.02, package_store.n.01, pawnbroker's_shop.n.01, perfumery.n.02, pet_shop.n.01, pizzeria.n.01, repair_shop.n.01, salon.n.02, shoe_shop.n.01, specialty_store.n.01, thriftshop.n.01, tobacco_shop.n.01, toyshop.n.01
#
#
# Word: broader
# Synonyms: wide, broad
# Antonyms: narrow
# Hypernyms:
# Hyponyms:
#
#
# Word: choice
# Synonyms: choice, pick, selection
# Antonyms:
# Hypernyms: decision_making.n.01
# Hyponyms: favorite.n.01, pleasure.n.03, way.n.10
#
#
# Word: channel
# Synonyms: channel, transmission_channel
# Antonyms:
# Hypernyms: transmission.n.02
# Hyponyms:
#
#
# Word: several
# Synonyms: several
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: east
# Synonyms: east, due_east, eastward, E
# Antonyms:
# Hypernyms: cardinal_compass_point.n.01
# Hyponyms:
#
#
# Word: west
# Synonyms: West, Occident
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: besides
# Synonyms: besides, in_any_case
# Antonyms:
# Hypernyms:
# Hyponyms:
#
#
# Word: dance
# Synonyms: dance
# Antonyms:
# Hypernyms: art.n.01
# Hyponyms: choreography.n.02, extension.n.08
#
#
# Word: music
# Synonyms: music
# Antonyms:
# Hypernyms: auditory_communication.n.01
# Hyponyms: antiphony.n.01, bach.n.02, ballet.n.02, beethoven.n.02, brahms.n.02, chopin.n.01, dance_music.n.02, gilbert_and_sullivan.n.01, handel.n.02, harmony.n.02, haydn.n.02, instrumental_music.n.01, monophony.n.01, mozart.n.02, music_genre.n.01, musical_composition.n.01, overture.n.01, part_music.n.01, pizzicato.n.01, polyphony.n.01, polytonality.n.01, popularism.n.01, prelude.n.02, refrain.n.01, section.n.01, serialism.n.01, stravinsky.n.02, syncopation.n.03, ta'ziyeh.n.01, tune.n.01, vocal_music.n.01, wagner.n.03
#
#
# Word: eat
# Synonyms: eat
# Antonyms:
# Hypernyms: consume.v.02, eat.v.02
# Hyponyms: devour.v.03, devour.v.04, dunk.v.03, eat_up.v.01, fare.v.02, fill_up.v.04, garbage_down.v.01, gluttonize.v.01, gobble.v.01, nibble.v.03, peck.v.02, pick_at.v.02, pitch_in.v.01, ruminate.v.01, slurp.v.01, wash_down.v.01, wolf.v.01
#
#
# Word: nationality
# Synonyms: nationality
# Antonyms:
# Hypernyms: people.n.01
# Hyponyms:

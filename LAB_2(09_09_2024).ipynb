# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashutosh-Gairola/NLP/blob/main/LAB_2(09_09_2024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Program to find the word "the" in the brown corpus

# %%
import re
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %%
from nltk.corpus import brown

# %%
brown_corpus=brown.sents()
all_words=[words.lower() for sentence in brown_corpus for words in sentence]
pattern=r'\bthe\b'

# %%
instances_of_the=[word for word in all_words if re.match(pattern,word)]

# %%
print("instances:",instances_of_the)
# Out:
# instances: ['the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the',
# ...

# %%
count_len=len(instances_of_the)
print("Number of the instances of 'the' is:",count_len)
# Out:
# Number of the instances of 'the' is: 69971

# %% [markdown]
# # Program to print all the bigrams and trigrams from a given corpus and sort them by frequency

# %%
from nltk import bigrams,trigrams

# %%
brown_corpus=brown.sents()
all_words=[words.lower() for sentence in brown_corpus for words in sentence]

# %%
all_bigram=list(bigrams(all_words))
all_trigram=list(trigrams(all_words))

# %%
print("Bigrams:",all_bigram[:10])
# Out:
# Bigrams: [('the', 'fulton'), ('fulton', 'county'), ('county', 'grand'), ('grand', 'jury'), ('jury', 'said'), ('said', 'friday'), ('friday', 'an'), ('an', 'investigation'), ('investigation', 'of'), ('of', "atlanta's")]

# %%
print("Trigrams:",all_trigram[:10])
# Out:
# Trigrams: [('the', 'fulton', 'county'), ('fulton', 'county', 'grand'), ('county', 'grand', 'jury'), ('grand', 'jury', 'said'), ('jury', 'said', 'friday'), ('said', 'friday', 'an'), ('friday', 'an', 'investigation'), ('an', 'investigation', 'of'), ('investigation', 'of', "atlanta's"), ('of', "atlanta's", 'recent')]

# %% [markdown]
# # Program to read text from a file and perform tokenization on sentence and word level Tokenizer in python nltk

# %%
from nltk.tokenize import word_tokenize

# %%
sample_sentence=" The output of the code will be the text content of the PDF document. "
tokens=word_tokenize(sample_sentence)

# %%
print(tokens)
# Out:
# ['The', 'output', 'of', 'the', 'code', 'will', 'be', 'the', 'text', 'content', 'of', 'the', 'PDF', 'document', '.']

# %%
whitespace_tokens=sample_sentence.split()
print(whitespace_tokens)
# Out:
# ['The', 'output', 'of', 'the', 'code', 'will', 'be', 'the', 'text', 'content', 'of', 'the', 'PDF', 'document.']

# %% [markdown]
# # Word Tokenizer

# %%
# !pip install pymupdf

# %%
import fitz

# %%
pdf_path="/content/drive/MyDrive/Colab Notebooks/NLP_Sem7_pythonLab/the-enchanted-forest-adventure.pdf"
# pdf_path="/content/drive/MyDrive/Colab Notebooks/NLP_Sem7_pythonLab/SeventhSense-obooko-hor0070.pdf"
# pdf_path="/content/drive/MyDrive/Colab Notebooks/NLP_Sem7_pythonLab/short-stories-and-other-writings-obooko.pdf"

# %%
def extract_text_from_pdf(pdf_path):
    doc=fitz.open(pdf_path)
    text=""
    for page_num in range(doc.page_count):
        page=doc.load_page(page_num)
        text+=page.get_text()
    doc.close()
    return text

# %%
pdf_text= extract_text_from_pdf(pdf_path)

# %%
tokens=word_tokenize(pdf_text)
print(tokens)
# Out:
# ['www.ohmytales.com', 'The', 'Enchanted', 'Forest', 'Adventure', 'Fantastic', 'story', '•', '5-6', 'years', 'old', 'www.ohmytales.com', 'Chapter', '1', ':', 'The', 'Enchanted', 'Forest', 'Once', 'upon', 'a', 'time', ',', 'in', 'a', 'magical', 'land', 'far', ',', 'far', 'away', ',', 'there', 'was', 'a', 'little', 'girl', 'named', 'Lily', '.', 'She', 'was', 'a', 'curious', 'and', 'adventurous', 'six-year-old', 'who', 'loved', 'exploring', 'the', 'world', 'around', 'her', '.', 'One', 'sunny', 'morning', ',', 'Lily', 'decided', 'to', 'venture', 'into', 'the', 'Enchanted', 'Forest', ',', 'a', 'place', 'full', 'of', 'wonder', 'and', 'mystery', '.', 'As', 'Lily', 'made', 'her', 'way', 'through', 'the', 'tall', 'trees', ',', 'she', 'could', "n't", 'help', 'but', 'notice', 'the', 'vibrant', 'colors', 'that', 'surrounded', 'her', '.', 'The', 'leaves', 'were', 'a', 'mixture', 'of', 'dazzling', 'greens', ',', 'oranges', ',', 'and', 'purples', ',', 'and', 'the', 'air', 'was', 'filled', 'with', 't
# ...

# %%
whitespace_tokens=pdf_text.split()
print(whitespace_tokens)
# Out:
# ['www.ohmytales.com', 'The', 'Enchanted', 'Forest', 'Adventure', 'Fantastic', 'story', '•', '5-6', 'years', 'old', 'www.ohmytales.com', 'Chapter', '1:', 'The', 'Enchanted', 'Forest', 'Once', 'upon', 'a', 'time,', 'in', 'a', 'magical', 'land', 'far,', 'far', 'away,', 'there', 'was', 'a', 'little', 'girl', 'named', 'Lily.', 'She', 'was', 'a', 'curious', 'and', 'adventurous', 'six-year-old', 'who', 'loved', 'exploring', 'the', 'world', 'around', 'her.', 'One', 'sunny', 'morning,', 'Lily', 'decided', 'to', 'venture', 'into', 'the', 'Enchanted', 'Forest,', 'a', 'place', 'full', 'of', 'wonder', 'and', 'mystery.', 'As', 'Lily', 'made', 'her', 'way', 'through', 'the', 'tall', 'trees,', 'she', "couldn't", 'help', 'but', 'notice', 'the', 'vibrant', 'colors', 'that', 'surrounded', 'her.', 'The', 'leaves', 'were', 'a', 'mixture', 'of', 'dazzling', 'greens,', 'oranges,', 'and', 'purples,', 'and', 'the', 'air', 'was', 'filled', 'with', 'the', 'sweet', 'scent', 'of', 'wildflowers.', 'The', 'forest'
# ...

# %% [markdown]
# # Sentence Tokenizer

# %%
from nltk.tokenize import PunktSentenceTokenizer

# %%
tokenizer=PunktSentenceTokenizer()
tokenizer.train(pdf_text)

punkt_tokens=tokenizer.tokenize(pdf_text)

# %%
for index, sentence in enumerate(punkt_tokens, start=1):
    print(f"Sentence {index}: {sentence}\n")
# Out:
# Sentence 1: www.ohmytales.com
# The Enchanted Forest
# Adventure
# Fantastic story • 5-6 years old
# www.ohmytales.com
# Chapter 1: The Enchanted Forest
#
#  Once upon a time, in a magical land far, far away, there was a little girl named Lily.
#
# Sentence 2: She was a
# curious and adventurous six-year-old who loved exploring the world around her.
#
# Sentence 3: One sunny morning,
# Lily decided to venture into the Enchanted Forest, a place full of wonder and mystery.
#
# Sentence 4: As Lily made her way through the tall trees, she couldn't help but notice the vibrant colors that
# surrounded her.
#
# Sentence 5: The leaves were a mixture of dazzling greens, oranges, and purples, and the air was
# filled with the sweet scent of wildflowers.
#
# Sentence 6: The forest seemed to come alive with every step she took.
#
# Sentence 7: Suddenly, Lily heard a rustling sound coming from behind a gigantic tree trunk.
#
# Sentence 8: She cautiously
# ...

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
